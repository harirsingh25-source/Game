# %%
import time

print("Sleeping briefly")
time.sleep(1)  # Short sleep so the notebook remains runnable.
print("Done Sleeping")
# Out:
# Sleeping briefly
# Done Sleeping

# %%
import numpy as np

# %%
import sys
# !{sys.executable} -m pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (2.4.6)
#
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pwd
# Out:
# /Users/hari/neuefische_course/ds-python-basics

# %%
# !ls
# Out:
# 1_Getting_Started     4_Functions           pyproject.toml
# 2_Basics              First_Code_Hari.ipynb solution
# 3_Data_Structures     assets                uv.lock

# %%
# Try it out!

# %%
np.random.rand?
# Out:
# Signature: np.random.rand(*args)
# Docstring:
# rand(d0, d1, ..., dn)
#
# Random values in a given shape.
#
# .. note::
#     This is a convenience function for users porting code from Matlab,
#     and wraps `random_sample`. That function takes a
#     tuple to specify the size of the output, which is consistent with
#     other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
# Create an array of the given shape and populate it with
# random samples from a uniform distribution
# over ``[0, 1)``.
#
# Parameters
# ----------
# d0, d1, ..., dn : int, optional
#     The dimensions of the returned array, must be non-negative.
#     If no argument is given a single Python float is returned.
#
# Returns
# -------
# out : ndarray, shape ``(d0, d1, ..., dn)``
#     Random values.
#
# See Also
# --------
# random
#
# Examples
# --------
# >>> np.random.rand(3,2)
# array([[ 0.14022471,  0.96360618],  #random
#        [ 0.37601032,  0.25528411],  #random
#        [ 0.49313049,  0.94909878]]) #random
# Type:      method

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (3.0.4)
# Requirement already satisfied: numpy>=1.26.0 in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (3.0.4)
# Requirement already satisfied: numpy>=1.26.0 in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/hari/neuefische_course/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.rand(100)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
print('Congratulations you are now familiar with jupyter notebook')
# Out:
# Congratulations you are now familiar with jupyter notebook

# %%
# !pwd
# Out:
# /Users/hari/neuefische_course/ds-python-basics

# %%
# !ls
# Out:
# 1_Getting_Started     4_Functions           pyproject.toml
# 2_Basics              First_Code_Hari.ipynb solution
# 3_Data_Structures     assets                uv.lock
